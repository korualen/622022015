# %%
#nomor1
import pandas as pd
import numpy as np
from pathlib import Path
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
column_names = ['sepal_length','sepal_width','petal_length','petal_width','species']

df = pd.read_csv(url, header=None, names=column_names)
data_array = df.to_numpy()
print(data_array)
print(df.head())

print("Shape dari dataset:", data_array.shape)
print("Size dari dataset:", data_array.size)
# Out:
# [[5.1 3.5 1.4 0.2 'Iris-setosa']
#  [4.9 3.0 1.4 0.2 'Iris-setosa']
#  [4.7 3.2 1.3 0.2 'Iris-setosa']
#  [4.6 3.1 1.5 0.2 'Iris-setosa']
#  [5.0 3.6 1.4 0.2 'Iris-setosa']
#  [5.4 3.9 1.7 0.4 'Iris-setosa']
#  [4.6 3.4 1.4 0.3 'Iris-setosa']
#  [5.0 3.4 1.5 0.2 'Iris-setosa']
#  [4.4 2.9 1.4 0.2 'Iris-setosa']
#  [4.9 3.1 1.5 0.1 'Iris-setosa']
#  [5.4 3.7 1.5 0.2 'Iris-setosa']
#  [4.8 3.4 1.6 0.2 'Iris-setosa']
#  [4.8 3.0 1.4 0.1 'Iris-setosa']
#  [4.3 3.0 1.1 0.1 'Iris-setosa']
#  [5.8 4.0 1.2 0.2 'Iris-setosa']
#  [5.7 4.4 1.5 0.4 'Iris-setosa']
#  [5.4 3.9 1.3 0.4 'Iris-setosa']
#  [5.1 3.5 1.4 0.3 'Iris-setosa']
#  [5.7 3.8 1.7 0.3 'Iris-setosa']
#  [5.1 3.8 1.5 0.3 'Iris-setosa']
#  [5.4 3.4 1.7 0.2 'Iris-setosa']
#  [5.1 3.7 1.5 0.4 'Iris-setosa']
#  [4.6 3.6 1.0 0.2 'Iris-setosa']
#  [5.1 3.3 1.7 0.5 'Iris-setosa']
#  [4.8 3.4 1.9 0.2 'Iris-setosa']
#  [5.0 3.0 1.6 0.2 'Iris-setosa']
#  [5.0 3.4 1.6 0.4 'Iris-setosa']
#  [5.2 3.5 1.5 0.2 'Iris-setosa']
# ...

# %% [markdown]
# # Nomor 2

# %%
setosa = df[df['species'] == 'Iris-setosa']
versicolor = df[df['species'] == 'Iris-versicolor']
virginica = df[df['species'] == 'Iriss-virginica']

# Kelompokkan Data

# %%
setosa.to_csv('setosa.csv', index=False)
versicolor.to_csv('versicolor.csv', index=False)
virginica.to_csv('virginica.csv', index=False)

# Simpan ke csv

# %%
np.save('setosa.npy' , setosa)
np.save('versicolor.npy' , versicolor)
np.save('virginica.npy' , virginica)

# Simpan ke npy

# %%
np.savez('iris_setosa.npz', setosa=setosa)
np.savez('iris_versicolor.npz', versicolor=versicolor)
np.savez('iris_virginica.npz', virginica=virginica)

# Simpan ke npz

# %%
print(setosa.head())
print(versicolor.head())
print(virginica.head())

# a. Ada 3 Kelas Bunga IRIS
# b. nama bunga sudah berdasarkan kelas
# c. size 250 setiap kelasnya
print("\nSize dari setosa: ", setosa.size)
print("Size dari versicolor: ", versicolor.size)
print("Size dari virginica: ", virginica.size)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#     sepal_length  sepal_width  petal_length  petal_width          species
# 50           7.0          3.2           4.7          1.4  Iris-versicolor
# 51           6.4          3.2           4.5          1.5  Iris-versicolor
# 52           6.9          3.1           4.9          1.5  Iris-versicolor
# 53           5.5          2.3           4.0          1.3  Iris-versicolor
# 54           6.5          2.8           4.6          1.5  Iris-versicolor
#      sepal_length  sepal_width  petal_length  petal_width         species
# ...

# %%
# Cek format manakah yang paling kecil tempat penyimpanannya?

import os

def get_file_size(filename):
  """Gets the size of a file in bytes."""
  if os.path.exists(filename):
    return os.path.getsize(filename)
  else:
    return 0

file_sizes = {}
for filename in ['setosa.csv', 'versicolor.csv', 'virginica.csv',
                 'setosa.npy', 'versicolor.npy', 'virginica.npy',
                 'iris_setosa.npz', 'iris_versicolor.npz', 'iris_virginica.npz']:
  file_sizes[filename] = get_file_size(filename)

# Sort files by size in ascending order
sorted_files = sorted(file_sizes.items(), key=lambda item: item[1])

print("File sizes (sorted by size):")
for filename, size in sorted_files:
  print(f"{filename}: {size} bytes")


# CSV bisa lebih kecil karena tidak ada overhead dari metadata yang ada di NPY/NPZ.
# Out:
# File sizes (sorted by size):
# setosa.csv: 1458 bytes
# virginica.csv: 1608 bytes
# versicolor.csv: 1658 bytes
# setosa.npy: 2191 bytes
# virginica.npy: 2194 bytes
# versicolor.npy: 2195 bytes
# iris_setosa.npz: 2329 bytes
# iris_virginica.npz: 2338 bytes
# iris_versicolor.npz: 2341 bytes

# %%
import numpy as np
np.save('setosa.npy', setosa.to_numpy)
np.save('versicolor.npy', versicolor.to_numpy)
np.save('virginica.npy', virginica.to_numpy)

# %% [markdown]
# # Bagian Baru

# %%
iris_setosa = np.load('setosa.npy', allow_pickle=True)
iris_versicolor = np.load('versicolor.npy', allow_pickle=True)
iris_virginica = np.load('virginica.npy', allow_pickle=True)
# load data npy nya

# %%
import matplotlib.pyplot as plt
import numpy as np

# Load the data
iris_setosa = np.load('setosa.npy', allow_pickle=True)
iris_versicolor = np.load('versicolor.npy', allow_pickle=True)
iris_virginica = np.load('virginica.npy', allow_pickle=True)

# Function to plot the data
def plot_iris_data(data, title):
    plt.figure(figsize=(10, 6))
    for i in range(4):
        plt.plot(data[:,i], label=f'Fitur {i+1}')
    plt.xlabel("Data ke- ")
    plt.ylabel("Iris (dalam cm)")
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.show()


# Plot each iris type
plot_iris_data(iris_setosa[:,:-1], "Iris Setosa")
plot_iris_data(iris_versicolor[:,:-1], "Iris Versicolor")
plot_iris_data(iris_virginica[:,:-1], "Iris Virginica")

# %%
def min_max_normalize(data):
    min_vals = data[:, :4].min(axis=0)
    max_vals = data[:, :4].max(axis=0)
    normalized = (data[:, :4] - min_vals) / (max_vals - min_vals)
    return normalized

norm_setosa = min_max_normalize(iris_setosa)
norm_versicolor = min_max_normalize(iris_versicolor)
norm_virginica = min_max_normalize(iris_virginica)

#normalisasikan datanya

# %%
def plot_normalized_iris_data(data, title):
    plt.figure(figsize=(10, 6))
    for i in range(4):
        plt.plot(data[:, i], label=f'Fitur {i+1}')
    plt.xlabel("Data ke-")
    plt.ylabel("Iris (normalized)")  # Changed y-label
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.show()

# Plot the normalized data for each iris type
plot_normalized_iris_data(norm_setosa, "Normalized Iris Setosa")
plot_normalized_iris_data(norm_versicolor, "Normalized Iris Versicolor")
plot_normalized_iris_data(norm_virginica, "Normalized Iris Virginica")

# %%
combined_data = np.vstack([
    np.hstack([norm_setosa, np.full((norm_setosa.shape[0], 1), 0)]),
    np.hstack([norm_versicolor, np.full((norm_versicolor.shape[0], 1), 1)]),
    np.hstack([norm_virginica, np.full((norm_virginica.shape[0], 1), 2)]),
])


#combine data untuk simpan ke cvs

# %%
columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
df_combined = pd.DataFrame(combined_data, columns=columns)
nim = "622022001"
df_combined.to_csv(f'percobaan3_{nim}.csv', index=False)
np.savez(f'percobaan3_{nim}.npz', data=combined_data)
print(pd.read_csv(f'percobaan3_{nim}.csv').head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0      0.533333     0.571429      0.444444          0.2        0
# 1      0.400000     0.333333      0.444444          0.2        0
# 2      0.266667     0.428571      0.333333          0.2        0
# 3      0.200000     0.380952      0.555556          0.2        0
# 4      0.466667     0.619048      0.444444          0.2        0

# %% [markdown]
# #nomor2
# a. ada 3 kelas bungan
# b. iya berdasarkan kelasnya
# c. 750

# %% [markdown]
# nomor2
# a.format virginica
# b.karna hasilnya menunjukan yang terkecil

# %%
# Langkah 1: Import Library
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Langkah 2: Load dan Persiapkan Data
iris = load_iris()
X = iris.data
y = iris.target

# Virginica (2) vs Non-Virginica (0 dan 1)
y = np.where(y == 2, 1, -1)  # Virginica -> 1, lainnya -> -1

# Ambil dua fitur pertama
X = X[:, :2]

# Standarisasi
sc = StandardScaler()
X_std = sc.fit_transform(X)

# Split train dan test
X_train, X_test, y_train, y_test = train_test_split(X_std, y, test_size=0.2, random_state=1)

# Langkah 3: Buat Kelas Perceptron
class Perceptron:
    def __init__(self, eta=0.01, n_iter=50):
        self.eta = eta
        self.n_iter = n_iter

    def fit(self, X, y):
        self.w_ = np.zeros(1 + X.shape[1])
        self.errors_ = []

        for _ in range(self.n_iter):
            errors = 0
            for xi, target in zip(X, y):
                update = self.eta * (target - self.predict(xi))
                self.w_[1:] += update * xi
                self.w_[0] += update
                errors += int(update != 0.0)
            self.errors_.append(errors)
        return self

    def net_input(self, X):
        return np.dot(X, self.w_[1:]) + self.w_[0]

    def predict(self, X):
        return np.where(self.net_input(X) >= 0.0, 1, -1)

# Langkah 4: Latih Model
ppn = Perceptron(eta=0.1, n_iter=10)
ppn.fit(X_train, y_train)

# Langkah 5: Plot Decision Boundary
def plot_decision_regions(X, y, classifier, resolution=0.02):
    markers = ('s', 'x')
    colors = ('red', 'blue')
    cmap = plt.cm.RdBu

    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                           np.arange(x2_min, x2_max, resolution))

    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)

    plt.contourf(xx1, xx2, Z, alpha=0.3, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0],
                    y=X[y == cl, 1],
                    alpha=0.8,
                    c=colors[idx],
                    marker=markers[idx],
                    label='Virginica' if cl == 1 else 'Non-Virginica',
                    edgecolor='black')

# Plot
plot_decision_regions(X_std, y, classifier=ppn)
plt.xlabel('Fitur 1 (standarisasi)')
plt.ylabel('Fitur 2 (standarisasi)')
plt.title('Perceptron - Virginica vs Non-Virginica')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# Langkah 6: Simpan data (opsional)
np.savez("Percobaan3_12345678_virginica.npz", X=X_std, y=y)
# Out:
# <ipython-input-16-9d30bcced131>:75: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(x=X[y == cl, 0],

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Kelas Perceptron
class Perceptron:
    def __init__(self, eta=0.01, n_iter=50):
        self.eta = eta
        self.n_iter = n_iter

    def fit(self, X, y):
        self.w_ = np.zeros(1 + X.shape[1])
        self.errors_ = []

        for _ in range(self.n_iter):
            errors = 0
            for xi, target in zip(X, y):
                update = self.eta * (target - self.predict(xi))
                self.w_[1:] += update * xi
                self.w_[0] += update
                errors += int(update != 0.0)
            self.errors_.append(errors)
        return self

    def net_input(self, X):
        return np.dot(X, self.w_[1:]) + self.w_[0]

    def predict(self, X):
        return np.where(self.net_input(X) >= 0.0, 1, -1)

# Fungsi Plot
def plot_decision_regions(X, y, classifier, ax, title):
    markers = ('s', 'x')
    colors = ('red', 'blue')
    cmap = plt.cm.RdBu

    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, 0.02),
                           np.arange(x2_min, x2_max, 0.02))

    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)

    ax.contourf(xx1, xx2, Z, alpha=0.3, cmap=cmap)
    ax.set_xlim(xx1.min(), xx1.max())
    ax.set_ylim(xx2.min(), xx2.max())

    for idx, cl in enumerate(np.unique(y)):
        ax.scatter(x=X[y == cl, 0],
                   y=X[y == cl, 1],
                   alpha=0.8,
                   c=colors[idx],
                   marker=markers[idx],
                   label='Target' if cl == 1 else 'Lainnya',
                   edgecolor='black')
    ax.set_title(title)
    ax.set_xlabel('Fitur 1 (standarisasi)')
    ax.set_ylabel('Fitur 2 (standarisasi)')
    ax.legend(loc='upper left')

# Load Data
iris = load_iris()
X_all = iris.data[:, :2]  # Dua fitur pertama
sc = StandardScaler()
X_std_all = sc.fit_transform(X_all)

fig, axs = plt.subplots(1, 3, figsize=(18, 5))
kategori = [
    ('Setosa vs Non-Setosa', lambda y: np.where(y == 0, 1, -1), "Percobaan3_setosa.npz"),
    ('Versicolor vs Non-Versicolor', lambda y: np.where(y == 1, 1, -1), "Percobaan3_versicolor.npz"),
    ('Virginica vs Non-Virginica', lambda y: np.where(y == 2, 1, -1), "Percobaan3_virginica.npz")
]

# Proses untuk masing-masing klasifikasi biner
for ax, (title, label_func, filename) in zip(axs, kategori):
    y_all = label_func(iris.target)
    X_train, X_test, y_train, y_test = train_test_split(X_std_all, y_all, test_size=0.2, random_state=1)
    ppn = Perceptron(eta=0.1, n_iter=10)
    ppn.fit(X_train, y_train)
    plot_decision_regions(X_std_all, y_all, classifier=ppn, ax=ax, title=title)
    np.savez(filename, X=X_std_all, y=y_all)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-18-1bc3be4bbfd0>:52: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x=X[y == cl, 0],
